# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
data = pd.read_csv("tips_dataset.csv")

# %%
data.head(5)
# Out:
#    Total Bill     Sex Smoker    Time  Day  Size    Tip
# 0       43.71    Male     No   Lunch  Fri     6   8.60
# 1       95.56    Male     No  Dinner  Tue     2  10.40
# 2       75.88    Male     No  Dinner  Tue     4  13.60
# 3       63.88  Female     No  Dinner  Tue     4  10.16
# 4       24.04  Female    Yes   Lunch  Sat     5   3.56

# %%
data.tail(5)
# Out:
#      Total Bill     Sex Smoker    Time   Day  Size    Tip
# 145       13.32    Male     No  Dinner   Wed     3   2.01
# 146       64.86    Male    Yes   Lunch   Fri     2  12.53
# 147       55.24  Female    Yes   Lunch   Fri     4   7.30
# 148       14.63    Male     No   Lunch   Tue     1   2.33
# 149       35.08  Female     No  Dinner  Thur     6   4.80

# %%
data['Sex'] = data['Sex'].map({'Male': 0, 'Female': 1})
data['Smoker'] = data['Smoker'].map({'No': 0, 'Yes': 1})
data['Time'] = data['Time'].map({'Lunch': 1, 'Dinner': 2})
data['Day'] = data['Day'].map({'Mon': 1, 'Tue': 2, 'Wed': 3, 'Thur': 4, 'Fri':5, 'Sat':6, 'Sun':7}) 
data.head(5)
# Out:
#    Total Bill  Sex  Smoker  Time  Day  Size    Tip
# 0       43.71    0       0     1    5     6   8.60
# 1       95.56    0       0     2    2     2  10.40
# 2       75.88    0       0     2    2     4  13.60
# 3       63.88    1       0     2    2     4  10.16
# 4       24.04    1       1     1    6     5   3.56

# %%
x = data[['Total Bill','Smoker','Time','Day','Size']]
y = data['Tip']

# %%
from sklearn.model_selection import train_test_split
x_train,  x_test, y_train, y_test = train_test_split(x, y,test_size = 0.3, random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Intercept:", model.intercept_)
print("Coefficients:",model.coef_)
# Out:
# Intercept: -0.6488823568068725
# Coefficients: [ 0.14275625 -0.01815034  0.16372443  0.06857385  0.18877176]

# %%
#prediction of test set
y_pred_model = model.predict(x_test)

#predict values
print("Prediction for test set: {} ".format(y_pred_model))
# Out:
# Prediction for test set: [ 2.50784083 14.08081273 13.91089014  3.81280092  3.19630213  5.60867455
#   2.80571052 13.83504498 12.17714868 10.07169856  3.68602529 13.77800152
#   4.50201671  9.56539993  2.35211658  7.45694997 12.03551008  3.27503984
#   5.96264915 13.26316299  7.85383058  4.34376967  9.47627488  2.62013221
#  14.90874277  6.09338173 11.62884393  9.77322625 12.57729252 12.76695376
#  10.37490596  3.51162185  9.1669474  12.69366201  6.25799668 12.19623503
#   6.09509719  8.25427614  8.23448547 10.32566933  8.78897685  3.15567691
#   5.4258957   3.17643633  2.86602071]

# %%
from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred_model)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_model)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_model))
print('R squared: {:.2f}'.format(mlr.score(x,y)*100))
print('Mean absolute error: ',meanAbErr)
print('Mean squared error: ',meanSqErr)
print('Root Mean squared error: ',rootMeanSqErr)
# Out:
# R squared: 83.72
# Mean absolute error:  1.4343375776920042
# Mean squared error:  3.771699743498864
# Root Mean squared error:  1.9420864407896123

# %%
model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred_model})
model_diff.head()
# Out:
#      Actual value  Predicted value
# 128          2.10         2.507841
# 11          19.27        14.080813
# 118          9.54        13.910890
# 15           2.89         3.812801
# 123          3.97         3.196302

# %%
plt.scatter(y_test, y_pred_mode)
plt.plot([y_test.min(),y_test.max()],[y_test.min(), y_test.max()],'red')
plt.show()
