# %% [markdown]
# # 2022/2024 Q3 Navie Bayes Classification

# %% [markdown]
# # (a) Encode the data.

# %%
import pandas as pd
data = {
    'Weather' : ['Sunny','Sunny','Overcast','Rainy','Rainy','Rainy','Overcast',
                 'Sunny','Sunny','Rainy','Sunny','Overcast','Overcast','Rainy'],
    'Temp' : ['Hot','Hot','Hot','Mild','Cool','Cool','Cool','Mild','Cool','Mild',
             'Mild','Mild','Hot','Mild'],
    'Play' : ['No','No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes',
             'Yes', 'No']
}

df = pd.DataFrame(data)

#Initialize labe encode
label_Weather  = LabelEncoder()
label_Temp = LabelEncoder()
label_Play = LabelEncoder()

#encode the categorical columns
df['Weather'] = label_Weather.fit_transform(df['Weather'])
df['Temp'] = label_Temp.fit_transform(df['Temp'])
df['Play'] = label_Play.fit_transform(df['Play'])

print(df)
# Out:
#     Weather  Temp  Play
# 0         2     1     0
# 1         2     1     0
# 2         0     1     1
# 3         1     2     1
# 4         1     0     1
# 5         1     0     0
# 6         0     0     1
# 7         2     2     0
# 8         2     0     1
# 9         1     2     1
# 10        2     2     1
# 11        0     2     1
# 12        0     1     1
# 13        1     2     0

# %% [markdown]
# # (b) Setup features and target into X and Y, respectively.

# %%
X = df[['Weather','Temp']]
y = df['Play']

print("Features (X):  ")
print(X)

print('\n')

print('Target (y): ')
print(y)
# Out:
# Features (X):
#     Weather  Temp
# 0         2     1
# 1         2     1
# 2         0     1
# 3         1     2
# 4         1     0
# 5         1     0
# 6         0     0
# 7         2     2
# 8         2     0
# 9         1     2
# 10        2     2
# 11        0     2
# 12        0     1
# 13        1     2
#
#
# Target (y):
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: Play, dtype: int64

# %% [markdown]
# # (c) Build the Naive Bayes model and train the model using the given training data.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 125)

from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # (d) Predict the output for the new instance, <Weather = Overcast , Temp = Mild>.

# %%
# New instance
new_instance = pd.DataFrame({
    'Weather': ['Overcast'],
    'Temp': ['Mild']
})

# One-hot encode the new instance
new_instance_encoded = pd.get_dummies(new_instance)

# Align columns with training data
new_instance_encoded = new_instance_encoded.reindex(columns=X_train.columns, fill_value=0)

# Predict class label
predicted_class = model.predict(new_instance_encoded)

# Predict class probabilities
class_probabilities = model.predict_proba(new_instance_encoded)

print("Predicted class:", 'Yes' if predicted_class[0] == 1 else 'No')
print("Class probabilities [No, Yes]:", class_probabilities)
# Out:
# Predicted class: Yes
# Class probabilities [No, Yes]: [[0.01257446 0.98742554]]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score
)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average = 'weighted')

print('Accuracy: ',accuracy)
print('F1 score:  ',f1_score)
# Out:
# Accuracy:  0.4
# F1 score:   <function f1_score at 0x00000212097A1A80>
